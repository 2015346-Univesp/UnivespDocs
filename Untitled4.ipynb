# %% [markdown]
# <a href="https://colab.research.google.com/github/2015346-Univesp/UnivespDocs/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('aeronave.csv', sep=';')

# %%
df1.head(5)
# Out:
#    codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0               81756              PTJBE                         ***
# 1               81747              PTSHY                         ***
# 2               81746              PTJOE                         ***
# 3               81745              PRAQV                         ***
# 4               81743              PRAYW                         ***
#
#   aeronave_tipo_veiculo      aeronave_fabricante  aeronave_modelo  \
# 0                 AVIÃO          CESSNA AIRCRAFT             182P
# 1                 AVIÃO                  EMBRAER        EMB-110P1
# 2                 AVIÃO          CESSNA AIRCRAFT            U206F
# 3                 AVIÃO  AEROSPATIALE AND ALENIA      ATR-72-212A
# 4                 AVIÃO                  EMBRAER  ERJ 190-200 IGW
#
#   aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# 0               C182              PISTÃO                 MONOMOTOR
# ...
